# %%
import pandas as pd
df = pd.read_csv('/content/Meteorite_Landings.csv', nrows=5)
df
# Out:
#        name   id nametype     recclass  mass (g)  fall  \
# 0    Aachen    1    Valid           L5        21  Fell
# 1    Aarhus    2    Valid           H6       720  Fell
# 2      Abee    6    Valid          EH4    107000  Fell
# 3  Acapulco   10    Valid  Acapulcoite      1914  Fell
# 4   Achiras  370    Valid           L6       780  Fell
#
#                      year    reclat    reclong           GeoLocation
# 0  01/01/1880 12:00:00 AM  50.77500    6.08333     (50.775, 6.08333)
# 1  01/01/1951 12:00:00 AM  56.18333   10.23333  (56.18333, 10.23333)
# 2  01/01/1952 12:00:00 AM  54.21667 -113.00000    (54.21667, -113.0)
# 3  01/01/1976 12:00:00 AM  16.88333  -99.90000     (16.88333, -99.9)
# 4  01/01/1902 12:00:00 AM -33.16667  -64.95000   (-33.16667, -64.95)

# %%
df.name
# Out:
# 0      Aachen
# 1      Aarhus
# 2        Abee
# 3    Acapulco
# 4     Achiras
# Name: name, dtype: object

# %%
df.columns
# Out:
# Index(['name', 'id', 'nametype', 'recclass', 'mass (g)', 'fall', 'year',
#        'reclat', 'reclong', 'GeoLocation'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
import pandas as pd
df = pd.read_csv('/content/Meteorite_Landings.csv')

# %%
import requests

response = requests.get('https://data.nasa.gov/resource/gh4g-9sfh.json',params={'$limit': 50_000})

if response.ok:
  payload = response.json()
else:
  print(f'Request was not successful  and returned code: {response.status_code}.')
  payload = None

# %%
import pandas as pd
df=pd.DataFrame(payload)
df.head(4)
# Out:
#        name  id nametype     recclass    mass  fall                     year  \
# 0    Aachen   1    Valid           L5      21  Fell  1880-01-01T00:00:00.000
# 1    Aarhus   2    Valid           H6     720  Fell  1951-01-01T00:00:00.000
# 2      Abee   6    Valid          EH4  107000  Fell  1952-01-01T00:00:00.000
# 3  Acapulco  10    Valid  Acapulcoite    1914  Fell  1976-01-01T00:00:00.000
#
#       reclat      reclong                                        geolocation  \
# 0  50.775000     6.083330     {'latitude': '50.775', 'longitude': '6.08333'}
# 1  56.183330    10.233330  {'latitude': '56.18333', 'longitude': '10.23333'}
# 2  54.216670  -113.000000    {'latitude': '54.21667', 'longitude': '-113.0'}
# 3  16.883330   -99.900000     {'latitude': '16.88333', 'longitude': '-99.9'}
#
#   :@computed_region_cbhk_fwbd :@computed_region_nnqa_25f4
# 0                         NaN                         NaN
# 1                         NaN                         NaN
# ...

# %%
df.shape
# Out:
# (45716, 12)

# %%
df.columns
# Out:
# Index(['name', 'id', 'nametype', 'recclass', 'mass', 'fall', 'year', 'reclat',
#        'reclong', 'geolocation', ':@computed_region_cbhk_fwbd',
#        ':@computed_region_nnqa_25f4'],
#       dtype='object')

# %%
df.dtypes
# Out:
# name                           object
# id                             object
# nametype                       object
# recclass                       object
# mass                           object
# fall                           object
# year                           object
# reclat                         object
# reclong                        object
# geolocation                    object
# :@computed_region_cbhk_fwbd    object
# :@computed_region_nnqa_25f4    object
# dtype: object

# %%
df.head(4)
# Out:
#        name  id nametype     recclass    mass  fall                     year  \
# 0    Aachen   1    Valid           L5      21  Fell  1880-01-01T00:00:00.000
# 1    Aarhus   2    Valid           H6     720  Fell  1951-01-01T00:00:00.000
# 2      Abee   6    Valid          EH4  107000  Fell  1952-01-01T00:00:00.000
# 3  Acapulco  10    Valid  Acapulcoite    1914  Fell  1976-01-01T00:00:00.000
#
#       reclat      reclong                                        geolocation  \
# 0  50.775000     6.083330     {'latitude': '50.775', 'longitude': '6.08333'}
# 1  56.183330    10.233330  {'latitude': '56.18333', 'longitude': '10.23333'}
# 2  54.216670  -113.000000    {'latitude': '54.21667', 'longitude': '-113.0'}
# 3  16.883330   -99.900000     {'latitude': '16.88333', 'longitude': '-99.9'}
#
#   :@computed_region_cbhk_fwbd :@computed_region_nnqa_25f4
# 0                         NaN                         NaN
# 1                         NaN                         NaN
# ...

# %%
df.tail(4)
# Out:
#              name     id nametype              recclass  mass   fall  \
# 45712      Zinder  30409    Valid  Pallasite, ungrouped    46  Found
# 45713        Zlin  30410    Valid                    H4   3.3  Found
# 45714   Zubkovsky  31357    Valid                    L6  2167  Found
# 45715  Zulu Queen  30414    Valid                  L3.7   200  Found
#
#                           year     reclat      reclong  \
# 45712  1999-01-01T00:00:00.000  13.783330     8.966670
# 45713  1939-01-01T00:00:00.000  49.250000    17.666670
# 45714  2003-01-01T00:00:00.000  49.789170    41.504600
# 45715  1976-01-01T00:00:00.000  33.983330  -115.683330
#
#                                              geolocation  \
# 45712   {'latitude': '13.78333', 'longitude': '8.96667'}
# 45713     {'latitude': '49.25', 'longitude': '17.66667'}
# 45714   {'latitude': '49.78917', 'longitude': '41.5046'}
# 45715  {'latitude': '33.98333', 'longitude': '-115.68...
#
# ...

# %%
df.info(4)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45716 entries, 0 to 45715
# Data columns (total 12 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         45716 non-null  object
#  1   id                           45716 non-null  object
#  2   nametype                     45716 non-null  object
#  3   recclass                     45716 non-null  object
#  4   mass                         45585 non-null  object
#  5   fall                         45716 non-null  object
#  6   year                         45425 non-null  object
#  7   reclat                       38401 non-null  object
#  8   reclong                      38401 non-null  object
#  9   geolocation                  38401 non-null  object
#  10  :@computed_region_cbhk_fwbd  1659 non-null   object
#  11  :@computed_region_nnqa_25f4  1659 non-null   object
# dtypes: object(12)
# memory usage: 4.2+ MB

# %%
df.name
# Out:
# 0            Aachen
# 1            Aarhus
# 2              Abee
# 3          Acapulco
# 4           Achiras
#             ...
# 45711    Zillah 002
# 45712        Zinder
# 45713          Zlin
# 45714     Zubkovsky
# 45715    Zulu Queen
# Name: name, Length: 45716, dtype: object

# %%
df[['name','mass']]
# Out:
#              name    mass
# 0          Aachen      21
# 1          Aarhus     720
# 2            Abee  107000
# 3        Acapulco    1914
# 4         Achiras     780
# ...           ...     ...
# 45711  Zillah 002     172
# 45712      Zinder      46
# 45713        Zlin     3.3
# 45714   Zubkovsky    2167
# 45715  Zulu Queen     200
#
# [45716 rows x 2 columns]

# %%
df[100:104]
# Out:
#               name     id nametype       recclass   mass  fall  \
# 100         Benton   5026    Valid            LL6   2840  Fell
# 101         Berduc  48975    Valid             L6    270  Fell
# 102         Béréba   5028    Valid  Eucrite-mmict  18000  Fell
# 103  Berlanguillas   5029    Valid             L6   1440  Fell
#
#                         year      reclat     reclong  \
# 100  1949-01-01T00:00:00.000   45.950000  -67.550000
# 101  2008-01-01T00:00:00.000  -31.910000  -58.328330
# 102  1924-01-01T00:00:00.000   11.650000   -3.650000
# 103  1811-01-01T00:00:00.000   41.683330   -3.800000
#
#                                           geolocation  \
# 100      {'latitude': '45.95', 'longitude': '-67.55'}
# 101  {'latitude': '-31.91', 'longitude': '-58.32833'}
# 102       {'latitude': '11.65', 'longitude': '-3.65'}
# 103     {'latitude': '41.68333', 'longitude': '-3.8'}
#
#     :@computed_region_cbhk_fwbd :@computed_region_nnqa_25f4
# ...

# %%
df.iloc[100:104,[0,3,4,6]]
# Out:
#               name       recclass   mass                     year
# 100         Benton            LL6   2840  1949-01-01T00:00:00.000
# 101         Berduc             L6    270  2008-01-01T00:00:00.000
# 102         Béréba  Eucrite-mmict  18000  1924-01-01T00:00:00.000
# 103  Berlanguillas             L6   1440  1811-01-01T00:00:00.000

# %%
df.iloc[100:104,[4, 5]]
# Out:
#       mass  fall
# 100   2840  Fell
# 101    270  Fell
# 102  18000  Fell
# 103   1440  Fell

# %%
(df['mass'].astype(float)>50)&(df.fall == 'Found')
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 45711     True
# 45712    False
# 45713    False
# 45714     True
# 45715     True
# Length: 45716, dtype: bool

# %%
le6=1000
df[(df['mass']>str(le6)) & (df.fall == 'fell')]
# Out:
# Empty DataFrame
# Columns: [name, id, nametype, recclass, mass, fall, year, reclat, reclong, geolocation, :@computed_region_cbhk_fwbd, :@computed_region_nnqa_25f4]
# Index: []

# %%
df.query(" 'mass'> le6 and fall 'fell' ")
# Out:
# Traceback (most recent call last):
#
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-33-f7ab0b54752d>", line 1, in <cell line: 1>
#     df.query(" 'mass'> le6 and fall 'fell' ")
#
#   File "/usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py", line 331, in wrapper
#     return func(*args, **kwargs)
#
#   File "/usr/local/lib/python3.10/dist-packages/pandas/core/frame.py", line 4474, in query
#     res = self.eval(expr, **kwargs)
#
#   File "/usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py", line 331, in wrapper
#     return func(*args, **kwargs)
#
#   File "/usr/local/lib/python3.10/dist-packages/pandas/core/frame.py", line 4612, in eval
#     return _eval(expr, inplace=inplace, **kwargs)
#
#   File "/usr/local/lib/python3.10/dist-packages/pandas/core/computation/eval.py", line 353, in eval
# ...

# %%
df.fall.value_counts()
# Out:
# Found    44609
# Fell      1107
# Name: fall, dtype: int64

# %%
df['mass'].mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-140641e775bb> in <cell line: 1>()
# ----> 1 df['mass'].mean()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11845             **kwargs,
#   11846         ):
# > 11847             return NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11848
#   11849         setattr(cls, "mean", mean)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11399         **kwargs,
#   11400     ) -> Series | float:
# > 11401         return self._stat_function(
#   11402             "mean", nanops.nanmean, axis, skipna, level, numeric_only, **kwargs
#   11403         )
#
# ...

# %%
df['mass'].quantile([0.01,0.05,0.5,0.95,0.99])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-7f9d7db85ccf> in <cell line: 1>()
# ----> 1 df['mass'].quantile([0.01,0.05,0.5,0.95,0.99])
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in quantile(self, q, interpolation)
#    2681         df = self.to_frame()
#    2682
# -> 2683         result = df.quantile(q=q, interpolation=interpolation, numeric_only=False)
#    2684         if result.ndim == 2:
#    2685             result = result.iloc[:, 0]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in quantile(self, q, axis, numeric_only, interpolation, method)
#   11319             # error: Argument "qs" to "quantile" of "BlockManager" has incompatible type
#   11320             # "Index"; expected "Float64Index"
# > 11321             res = data._mgr.quantile(
# ...

# %%
df.loc[df['mass'].idxmax()]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-ed5151e291c0> in <cell line: 1>()
# ----> 1 df.loc[df['mass'].idxmax()]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in idxmax(self, axis, skipna, *args, **kwargs)
#    2562         nan
#    2563         """
# -> 2564         i = self.argmax(axis, skipna, *args, **kwargs)
#    2565         if i == -1:
#    2566             return np.nan
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/base.py in argmax(self, axis, skipna, *args, **kwargs)
#     653             # error: Incompatible return value type (got "Union[int, ndarray]", expected
#     654             # "int")
# --> 655             return nanops.nanargmax(  # type: ignore[return-value]
#     656                 delegate, skipna=skipna
#     657             )
#
# ...

# %%
df.recclass.nunique()
# Out:
# 466

# %%
df.recclass.unique()[:14]
# Out:
# array(['L5', 'H6', 'EH4', 'Acapulcoite', 'L6', 'LL3-6', 'H5', 'L',
#        'Diogenite-pm', 'Unknown', 'H4', 'H', 'Iron, IVA', 'CR2-an'],
#       dtype=object)

# %%
df.describe(include='all')
# Out:
#           name     id nametype recclass   mass   fall  \
# count    45716  45716    45716    45716  45585  45716
# unique   45716  45716        2      466  12576      2
# top     Aachen      1    Valid       L6    1.3  Found
# freq         1      1    45641     8285    171  44609
#
#                            year    reclat   reclong  \
# count                     45425     38401     38401
# unique                      266     12738     14640
# top     2003-01-01T00:00:00.000  0.000000  0.000000
# freq                       3323      6438      6214
#
#                                     geolocation :@computed_region_cbhk_fwbd  \
# count                                     38401                        1659
# unique                                    17100                          45
# top     {'latitude': '0.0', 'longitude': '0.0'}                          23
# freq                                       6214                         297
#
#        :@computed_region_nnqa_25f4
# ...
